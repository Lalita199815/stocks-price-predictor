# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (3.20.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: gast>=0.2.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: wheel>=0.26 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.35.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.5)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.25.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)

# %%
#import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
from sklearn.preprocessing import MinMaxScaler

# %%
#reading the dataset
df=pd.read_csv("NSE-TATAGLOBAL11.csv")
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
#setting index as date
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')

# %%
data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Close'])

for i in range(0,len(data)):
    new_dataset["Date"][i]=data['Date'][i]
    new_dataset["Close"][i]=data["Close"][i]

# %%
new_dataset.index=new_dataset.Date
new_dataset.drop("Date",axis=1,inplace=True)
final_dataset=new_dataset.values

train_data=final_dataset[0:987,:]
valid_data=final_dataset[987:,:]

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)

x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)

x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))

inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)

lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# 927/927 - 44s - loss: 0.0012 - 44s/epoch - 48ms/step

# %%
X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_closing_price=lstm_model.predict(X_test)
predicted_closing_price=scaler.inverse_transform(predicted_closing_price)

# %%
lstm_model.save("myNewModel.h5")

# %%
train_data=new_dataset[:987]
valid_data=new_dataset[987:]
valid_data['Predictions']=predicted_closing_price
plt.plot(train_data["Close"])
plt.plot(valid_data[['Close',"Predictions"]])
# Out:
# <ipython-input-14-397e778e3e61>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data['Predictions']=predicted_closing_price
# [<matplotlib.lines.Line2D at 0x27fea5ed640>,
#  <matplotlib.lines.Line2D at 0x27fea5ed670>]

# %%
# !pip3 install dash
# !pip3 install dash-html-components
# !pip3 install dash-core-components
# Out:
# Requirement already satisfied: dash in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from dash) (1.12)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from dash) (5.7.0)
# Requirement already satisfied: brotli in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: click>=5.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: six in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: dash-html-components in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: dash-core-components in c:\users\satyavrat dwivedi\anaconda3\lib\site-packages (2.0.0)

# %%
python stock_app.ipynb
# Out:
#   File "<ipython-input-16-9653a36a85b4>", line 1
#     python stock_app.ipynb
#            ^
# SyntaxError: invalid syntax
